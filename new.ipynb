# %%
import requests
import json
import pandas as pd

# %%
headers = {
    "sec-ch-ua-platform": '"Windows"',
    "Referer": "https://www.netflix.com/tudum/top10",
    "sec-ch-ua": '"Not?A_Brand";v="99", "Chromium";v="130"',
    "sec-ch-ua-model": '""',
    "sec-ch-ua-mobile": "?0",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/130.0.0.0 Safari/537.36",
    "DNT": "1",
    "sec-ch-ua-platform-version": '"15.0.0"',
}

response = requests.get(
    "https://www.netflix.com/tudum/top10/data/weeks/20241103-data.json", headers=headers
)

# %%
t = json.loads(response.text)

# %%
pd.DataFrame(t["global"])
# Out:
#         week        id    showId           category rank weeksInTopTen  \
# 0   20241103  80117526  80117526              films    6            15
# 1   20241103  81676888  81676888              films    3             2
# 2   20241103  81505323  81414644     tv-non-english    7             1
# 3   20241103  81670965  81670964                 tv    6             1
# 4   20241103  81351065  81351064     tv-non-english    8             1
# 5   20241103  81739319  81739319  films-non-english    9             3
# 6   20241103  81486271  81288983                 tv    3             1
# 7   20241103  81591575  81591574                 tv    2             2
# 8   20241103  81728818  81728818              films    5             3
# 9   20241103  81736885  81736884     tv-non-english    2             4
# 10  20241103  81591297  81591296                 tv    7             6
# 11  20241103  81628779  81303831                 tv    5             3
# ...

# %%
cookies = {
    "_sp_ses.cf1a": "*",
    "device_t": "WERhREJROjA.vtTxBcc1PKS4PJo-CbMoeG6tTsf_2-yE8Yc4aS1zvWU",
    "sessionid": "i7pys5kd8d7pz1po7tl97esfraoxdkua",
    "sessionid_sign": "v3:AQU3lOWBXiKOnnjQHknj0K9bOCWZMPdTy3Q/dMO7RL4=",
    "png": "79e80d4a-faff-4ff9-bfd9-d32e75956d4d",
    "etg": "79e80d4a-faff-4ff9-bfd9-d32e75956d4d",
    "cachec": "79e80d4a-faff-4ff9-bfd9-d32e75956d4d",
    "tv_ecuid": "79e80d4a-faff-4ff9-bfd9-d32e75956d4d",
    "cookiesSettings": '{"analytics":true,"advertising":true}',
    "cookiePrivacyPreferenceBannerProduction": "accepted",
    "_sp_id.cf1a": "3967f81c-1428-4d78-bff7-947e58dad5d3.1732028617.1.1732028791..9b7b8aaf-8e51-4b6d-b46e-1b351cf1b432..a9eb4409-eea1-4a07-ad28-d52ae790a06f.1732028617150.14",
}

headers = {
    "accept": "application/json",
    "accept-language": "en-GB,en-US;q=0.9,en;q=0.8",
    "content-type": "text/plain;charset=UTF-8",
    # 'cookie': '_sp_ses.cf1a=*; device_t=WERhREJROjA.vtTxBcc1PKS4PJo-CbMoeG6tTsf_2-yE8Yc4aS1zvWU; sessionid=i7pys5kd8d7pz1po7tl97esfraoxdkua; sessionid_sign=v3:AQU3lOWBXiKOnnjQHknj0K9bOCWZMPdTy3Q/dMO7RL4=; png=79e80d4a-faff-4ff9-bfd9-d32e75956d4d; etg=79e80d4a-faff-4ff9-bfd9-d32e75956d4d; cachec=79e80d4a-faff-4ff9-bfd9-d32e75956d4d; tv_ecuid=79e80d4a-faff-4ff9-bfd9-d32e75956d4d; cookiesSettings={"analytics":true,"advertising":true}; cookiePrivacyPreferenceBannerProduction=accepted; _sp_id.cf1a=3967f81c-1428-4d78-bff7-947e58dad5d3.1732028617.1.1732028791..9b7b8aaf-8e51-4b6d-b46e-1b351cf1b432..a9eb4409-eea1-4a07-ad28-d52ae790a06f.1732028617150.14',
    "dnt": "1",
    "origin": "https://www.tradingview.com",
    "priority": "u=1, i",
    "referer": "https://www.tradingview.com/",
    "sec-ch-ua": '"Not?A_Brand";v="99", "Chromium";v="130"',
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": '"Windows"',
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-site",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/130.0.0.0 Safari/537.36",
}

params = {
    "label-product": "screener-stock",
}

data = '{"columns":["name","description","logoid","update_mode","type","typespecs","close","pricescale","minmov","fractional","minmove2","currency","change","volume","relative_volume_10d_calc","market_cap_basic","fundamental_currency_code","price_earnings_ttm","earnings_per_share_diluted_ttm","earnings_per_share_diluted_yoy_growth_ttm","dividends_yield_current","sector.tr","market","sector","recommendation_mark","exchange"],"filter":[{"left":"is_primary","operation":"equal","right":true}],"ignore_unknown_fields":false,"options":{"lang":"en"},"range":[0,200000],"sort":{"sortBy":"name","sortOrder":"asc"},"symbols":{},"markets":["america"],"filter2":{"operator":"and","operands":[{"operation":{"operator":"or","operands":[{"operation":{"operator":"and","operands":[{"expression":{"left":"type","operation":"equal","right":"stock"}},{"expression":{"left":"typespecs","operation":"has","right":["common"]}}]}},{"operation":{"operator":"and","operands":[{"expression":{"left":"type","operation":"equal","right":"stock"}},{"expression":{"left":"typespecs","operation":"has","right":["preferred"]}}]}},{"operation":{"operator":"and","operands":[{"expression":{"left":"type","operation":"equal","right":"dr"}}]}},{"operation":{"operator":"and","operands":[{"expression":{"left":"type","operation":"equal","right":"fund"}},{"expression":{"left":"typespecs","operation":"has_none_of","right":["etf"]}}]}}]}}]}}'

response = requests.post(
    "https://scanner.tradingview.com/america/scan",
    params=params,
    cookies=cookies,
    headers=headers,
    data=data,
)

# %%
t = response.json()

# %%
# Out:
# ['name',
#  'description',
#  'logoid',
#  'update_mode',
#  'type',
#  'typespecs',
#  'close',
#  'pricescale',
#  'minmov',
#  'fractional',
#  'minmove2',
#  'currency',
#  'change',
#  'volume',
#  'relative_volume_10d_calc',
#  'market_cap_basic',
#  'fundamental_currency_code',
#  'price_earnings_ttm',
#  'earnings_per_share_diluted_ttm',
#  'earnings_per_share_diluted_yoy_growth_ttm',
#  'dividends_yield_current',
#  'sector.tr',
#  'market',
#  'sector',
#  'recommendation_mark',
#  'exchange']

# %%
df = pd.DataFrame(
    list(map(lambda x: x["d"], t["data"])), columns=json.loads(data)["columns"]
)

# %%
json.loads(
    '{"columns":["name","description","logoid","update_mode","type","typespecs","close","pricescale","minmov","fractional","minmove2","currency","change","volume","relative_volume_10d_calc","market_cap_basic","fundamental_currency_code","price_earnings_ttm","earnings_per_share_diluted_ttm","earnings_per_share_diluted_yoy_growth_ttm","dividends_yield_current","sector.tr","market","sector","recommendation_mark","exchange"],"filter":[{"left":"is_primary","operation":"equal","right":true}],"ignore_unknown_fields":false,"options":{"lang":"en"},"range":[0,200000],"sort":{"sortBy":"name","sortOrder":"asc"},"symbols":{},"markets":["america"],"filter2":{"operator":"and","operands":[{"operation":{"operator":"or","operands":[{"operation":{"operator":"and","operands":[{"expression":{"left":"type","operation":"equal","right":"stock"}},{"expression":{"left":"typespecs","operation":"has","right":["common"]}}]}},{"operation":{"operator":"and","operands":[{"expression":{"left":"type","operation":"equal","right":"stock"}},{"expression":{"left":"typespecs","operation":"has","right":["preferred"]}}]}},{"operation":{"operator":"and","operands":[{"expression":{"left":"type","operation":"equal","right":"dr"}}]}},{"operation":{"operator":"and","operands":[{"expression":{"left":"type","operation":"equal","right":"fund"}},{"expression":{"left":"typespecs","operation":"has_none_of","right":["etf"]}}]}}]}}]}}'
)
# Out:
# {'columns': ['name',
#   'description',
#   'logoid',
#   'update_mode',
#   'type',
#   'typespecs',
#   'close',
#   'pricescale',
#   'minmov',
#   'fractional',
#   'minmove2',
#   'currency',
#   'change',
#   'volume',
#   'relative_volume_10d_calc',
#   'market_cap_basic',
#   'fundamental_currency_code',
#   'price_earnings_ttm',
#   'earnings_per_share_diluted_ttm',
#   'earnings_per_share_diluted_yoy_growth_ttm',
#   'dividends_yield_current',
#   'sector.tr',
#   'market',
#   'sector',
#   'recommendation_mark',
#   'exchange'],
#  'filter': [{'left': 'is_primary', 'operation': 'equal', 'right': True}],
#  'ignore_unknown_fields': False,
#  'options': {'lang': 'en'},
#  'range': [0, 200000],
#  'sort': {'sortBy': 'name', 'sortOrder': 'asc'},
#  'symbols': {},
#  'markets': ['america'],
#  'filter2': {'operator': 'and',
#   'operands': [{'operation': {'operator': 'or',
#      'operands': [{'operation': {'operator': 'and',
# ...

# %%
cookies = {
    "_sp_ses.cf1a": "*",
    "device_t": "WERhREJROjA.vtTxBcc1PKS4PJo-CbMoeG6tTsf_2-yE8Yc4aS1zvWU",
    "sessionid": "i7pys5kd8d7pz1po7tl97esfraoxdkua",
    "sessionid_sign": "v3:AQU3lOWBXiKOnnjQHknj0K9bOCWZMPdTy3Q/dMO7RL4=",
    "png": "79e80d4a-faff-4ff9-bfd9-d32e75956d4d",
    "etg": "79e80d4a-faff-4ff9-bfd9-d32e75956d4d",
    "cachec": "79e80d4a-faff-4ff9-bfd9-d32e75956d4d",
    "tv_ecuid": "79e80d4a-faff-4ff9-bfd9-d32e75956d4d",
    "cookiesSettings": '{"analytics":true,"advertising":true}',
    "cookiePrivacyPreferenceBannerProduction": "accepted",
    "_sp_id.cf1a": "3967f81c-1428-4d78-bff7-947e58dad5d3.1732028617.1.1732030101..9b7b8aaf-8e51-4b6d-b46e-1b351cf1b432..a9eb4409-eea1-4a07-ad28-d52ae790a06f.1732028617150.19",
}

headers = {
    "accept": "application/json",
    "accept-language": "en-GB,en-US;q=0.9,en;q=0.8",
    "content-type": "text/plain;charset=UTF-8",
    # 'cookie': '_sp_ses.cf1a=*; device_t=WERhREJROjA.vtTxBcc1PKS4PJo-CbMoeG6tTsf_2-yE8Yc4aS1zvWU; sessionid=i7pys5kd8d7pz1po7tl97esfraoxdkua; sessionid_sign=v3:AQU3lOWBXiKOnnjQHknj0K9bOCWZMPdTy3Q/dMO7RL4=; png=79e80d4a-faff-4ff9-bfd9-d32e75956d4d; etg=79e80d4a-faff-4ff9-bfd9-d32e75956d4d; cachec=79e80d4a-faff-4ff9-bfd9-d32e75956d4d; tv_ecuid=79e80d4a-faff-4ff9-bfd9-d32e75956d4d; cookiesSettings={"analytics":true,"advertising":true}; cookiePrivacyPreferenceBannerProduction=accepted; _sp_id.cf1a=3967f81c-1428-4d78-bff7-947e58dad5d3.1732028617.1.1732030101..9b7b8aaf-8e51-4b6d-b46e-1b351cf1b432..a9eb4409-eea1-4a07-ad28-d52ae790a06f.1732028617150.19',
    "dnt": "1",
    "origin": "https://www.tradingview.com",
    "priority": "u=1, i",
    "referer": "https://www.tradingview.com/",
    "sec-ch-ua": '"Not?A_Brand";v="99", "Chromium";v="130"',
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": '"Windows"',
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-site",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/130.0.0.0 Safari/537.36",
}

params = {
    "label-product": "screener-coin",
}

data = '{"columns":["base_currency","base_currency_desc","base_currency_logoid","update_mode","type","typespecs","exchange","crypto_total_rank","close","pricescale","minmov","fractional","minmove2","currency","24h_close_change|5","market_cap_calc","fundamental_currency_code","24h_vol_cmc","circulating_supply","crypto_common_categories.tr"],"ignore_unknown_fields":false,"options":{"lang":"en"},"range":[0,200000],"sort":{"sortBy":"crypto_total_rank","sortOrder":"asc"},"symbols":{},"markets":["coin"]}'

response = requests.post(
    "https://scanner.tradingview.com/coin/scan",
    params=params,
    cookies=cookies,
    headers=headers,
    data=data,
)

# %%
[x["d"] for x in response.json()["data"]]
# Out:
# [['BTC',
#   'Bitcoin',
#   'crypto/XTVCBTC',
#   'streaming',
#   'spot',
#   ['crypto', 'cryptoasset', 'synthetic'],
#   'CRYPTO',
#   1,
#   91618.93,
#   100,
#   1,
#   'false',
#   0,
#   'USD',
#   1.1202224315442908,
#   1812633529538.91,
#   'USD',
#   73938738457.14243,
#   19784487,
#   ['Cryptocurrencies', 'Layer 1']],
#  ['ETH',
#   'Ethereum',
#   'crypto/XTVCETH',
#   'streaming',
#   'spot',
#   ['crypto', 'cryptoasset', 'synthetic'],
#   'CRYPTO',
#   2,
#   3093.06,
#   100,
#   1,
#   'false',
#   0,
#   'USD',
#   -0.015198452991516502,
#   372482630156.144,
#   'USD',
#   35115459635.113205,
#   120425284.39672816,
#   ['Smart contract platforms', 'Layer 1']],
#  ['USDT',
#   'Tether USDt',
#   'crypto/XTVCUSDT',
#   'streaming',
#   'spot',
#   ['crypto', 'cryptoasset', 'synthetic'],
#   'CRYPTO',
#   3,
#   1.00062,
#   100000,
#   1,
#   'false',
#   0,
#   'USD',
#   0.04599264117742431,
#   128230881121.8637,
#   'USD',
#   152713973358.8265,
# ...

# %%
list(map(lambda x: x["d"], response.json()["data"]))
# Out:
# [['BTC',
#   'Bitcoin',
#   'crypto/XTVCBTC',
#   'streaming',
#   'spot',
#   ['crypto', 'cryptoasset', 'synthetic'],
#   'CRYPTO',
#   1,
#   91618.93,
#   100,
#   1,
#   'false',
#   0,
#   'USD',
#   1.1202224315442908,
#   1812633529538.91,
#   'USD',
#   73938738457.14243,
#   19784487,
#   ['Cryptocurrencies', 'Layer 1']],
#  ['ETH',
#   'Ethereum',
#   'crypto/XTVCETH',
#   'streaming',
#   'spot',
#   ['crypto', 'cryptoasset', 'synthetic'],
#   'CRYPTO',
#   2,
#   3093.06,
#   100,
#   1,
#   'false',
#   0,
#   'USD',
#   -0.015198452991516502,
#   372482630156.144,
#   'USD',
#   35115459635.113205,
#   120425284.39672816,
#   ['Smart contract platforms', 'Layer 1']],
#  ['USDT',
#   'Tether USDt',
#   'crypto/XTVCUSDT',
#   'streaming',
#   'spot',
#   ['crypto', 'cryptoasset', 'synthetic'],
#   'CRYPTO',
#   3,
#   1.00062,
#   100000,
#   1,
#   'false',
#   0,
#   'USD',
#   0.04599264117742431,
#   128230881121.8637,
#   'USD',
#   152713973358.8265,
# ...

# %%
pd.DataFrame(
    [x["d"] for x in response.json()["data"]], columns=json.loads(data)["columns"]
)
# Out:
#     base_currency base_currency_desc base_currency_logoid update_mode  type  \
# 0             BTC            Bitcoin       crypto/XTVCBTC   streaming  spot
# 1             ETH           Ethereum       crypto/XTVCETH   streaming  spot
# 2            USDT        Tether USDt      crypto/XTVCUSDT   streaming  spot
# 3             SOL             Solana       crypto/XTVCSOL   streaming  spot
# 4             BNB                BNB       crypto/XTVCBNB   streaming  spot
# ..            ...                ...                  ...         ...   ...
# 832          PERL           PERL.eco      crypto/XTVCPERL   streaming  spot
# 833          KALM               KALM      crypto/XTVCKALM   streaming  spot
# 834           PTS             Petals       crypto/XTVCPTS   streaming  spot
# 835           EVA            Evadore      crypto/XTVCEVAD   streaming  spot
# 836           ZBC              Zebec       crypto/XTVCZBC   streaming  spot
#
# ...

# %%
import requests

headers = {
    "accept": "*/*",
    "accept-language": "en-GB,en-US;q=0.9,en;q=0.8",
    "content-type": "application/json+protobuf",
    "dnt": "1",
    "origin": "https://vonatinfo.mav-start.hu",
    "priority": "u=1, i",
    "referer": "https://vonatinfo.mav-start.hu/",
    "sec-ch-ua": '"Not?A_Brand";v="99", "Chromium";v="130"',
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": '"Windows"',
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "cross-site",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/130.0.0.0 Safari/537.36",
    "x-client-data": "CMT6ygE=",
    "x-goog-api-key": "AIzaSyBsySapU85XJ3XcWCc61IowJlqck3gS5Tw",
    "x-goog-maps-api-salt": "1r3zM70FTY",
    "x-goog-maps-api-signature": "97925",
    "x-goog-maps-channel-id": "",
    "x-goog-maps-client-id": "",
    "x-user-agent": "grpc-web-javascript/0.1",
}

data = '[[[35.03211059260621,-2.236092165485503],[58.13839630262307,39.50429492357721]],7,null,"en-GB",4,"r@713000000",0,0,null,null,null,2]'

response = requests.post(
    "https://maps.googleapis.com/$rpc/google.internal.maps.mapsjs.v1.MapsJsInternalService/GetViewportInfo",
    headers=headers,
    data=data,
)

# %%
response.json()
# Out:
# ['Map data ©2024 GeoBasis-DE/BKG (©2009), Google',
#  [['obliques', [[57.32652122521708, 5.625], [58.81374171570782, 8.4375]]],
#   ['obliques', [[57.32652122521708, 11.25], [58.81374171570782, 16.875]]],
#   ['obliques', [[55.77657301866769, -2.8125], [57.32652122521708, 0]]],
#   ['obliques', [[55.77657301866769, 8.4375], [57.32652122521708, 16.875]]],
#   ['obliques', [[54.1624339680678, -2.8125], [55.77657301866769, 0]]],
#   ['obliques', [[54.1624339680678, 5.625], [55.77657301866769, 19.6875]]],
#   ['obliques', [[52.48278022207821, -2.8125], [54.1624339680678, 22.5]]],
#   ['obliques', [[50.73645513701065, -2.8125], [52.48278022207821, 25.3125]]],
#   ['obliques', [[48.92249926375824, -2.8125], [50.73645513701065, 22.5]]],
#   ['obliques', [[47.04018214480666, -2.8125], [48.92249926375824, 28.125]]],
#   ['obliques',
#    [[45.089035564831015, -2.8125], [47.04018214480666, 30.937499999999996]]],
#   ['obliques',
# ...

# %%
cookies = {
    "JSESSIONID": "6EFB3438F69C3D2456D08E5CD007D364.s31webva01-web",
    "jjJartSession": "1731772034221",
}

headers = {
    "Accept": "application/json, text/javascript, */*; q=0.01",
    "Accept-Language": "en-GB,en-US;q=0.9,en;q=0.8",
    "Connection": "keep-alive",
    # 'Cookie': 'JSESSIONID=6EFB3438F69C3D2456D08E5CD007D364.s31webva01-web; jjJartSession=1731772034221',
    "DNT": "1",
    "Referer": "https://www.viennaairport.com/passagiere",
    "Sec-Fetch-Dest": "empty",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "same-origin",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/130.0.0.0 Safari/537.36",
    "X-Requested-With": "XMLHttpRequest",
    "sec-ch-ua": '"Not?A_Brand";v="99", "Chromium";v="130"',
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": '"Windows"',
}

params = {
    "dummy": "R66ab89fX8e15c2f",
}

response = requests.get(
    "https://www.viennaairport.com/jart/prj3/va/data/flights/out.json",
    params=params,
    cookies=cookies,
    headers=headers,
)

# %%
import scrapethat as st

# %%
st.fromjson("https://www.viennaairport.com/jart/prj3/va/data/flights/out.json")
# Out:
# {'monitor': {'type': 'json',
#   'sendDate': '2024-11-19T17:00:03.240',
#   'stale': False,
#   'departure': [{'idx': 0,
#     'fn': 'OS 227',
#     'scheduledatetime': '2024-11-19T10:15:00Z',
#     'schedule': '2024-11-19T11:15:00.000',
#     'actualdatetime': '2024-11-19T10:17:00Z',
#     'actual': '2024-11-19T11:17:00.000',
#     'gate': 'F17',
#     'gateArea': 'F',
#     'status': {'code': 'AIR', 'description': 'airborne'},
#     'codeshares': [],
#     'aircraft': {'type': '320', 'description': 'Airbus 320'},
#     'airline': {'name': 'Austrian',
#      'webSite': 'www.austrian.com',
#      'iataCode': 'OS',
#      'icaoCode': 'AUA'},
#     'destinations': [{'name': 'Berlin Brandenburg',
#       'nameEN': 'Berlin',
#       'nameDE': 'Berlin',
#       'nameEN10': 'Berlin',
#       'nameDE10': 'Berlin',
#       'iataCode': 'BER',
#       'webSite': None,
#       'city': {'nameDE': 'Berlin',
#        'nameEN': 'Berlin',
# ...

# %%
t = response.json()

# %%
df = pd.json_normalize(t["monitor"]["departure"])

# %%
df.reset_index(drop=True, inplace=True)

# %%
df = df.explode("codeshares").explode("destinations")

# %%
df
# Out:
#      idx      fn      scheduledatetime                 schedule  \
# 0      0  A3 861  2024-11-19T09:50:00Z  2024-11-19T10:50:00.000
# 0      0  A3 861  2024-11-19T09:50:00Z  2024-11-19T10:50:00.000
# 1      1  EY 154  2024-11-19T09:50:00Z  2024-11-19T10:50:00.000
# 1      1  EY 154  2024-11-19T09:50:00Z  2024-11-19T10:50:00.000
# 2      2  OS 087  2024-11-19T09:50:00Z  2024-11-19T10:50:00.000
# ..   ...     ...                   ...                      ...
# 376  376  OS 515  2024-11-20T17:20:00Z  2024-11-20T18:20:00.000
# 377  377  OS 217  2024-11-20T17:30:00Z  2024-11-20T18:30:00.000
# 378  378  OS 565  2024-11-20T17:30:00Z  2024-11-20T18:30:00.000
# 379  379  BA 705  2024-11-20T17:40:00Z  2024-11-20T18:40:00.000
# 380  380  FR 075  2024-11-20T17:40:00Z  2024-11-20T18:40:00.000
#
#            actualdatetime                   actual  gate gateArea  \
# 0    2024-11-19T10:19:00Z  2024-11-19T11:19:00.000   C41        C
# ...

# %%
df["destinations"].apply(pd.Series)
# Out:
#                                      name        nameEN        nameDE  \
# 0            Athens International Airport        Athens         Athen
# 0            Athens International Airport        Athens         Athen
# 1                       Abu Dhabi Airport     Abu Dhabi     Abu Dhabi
# 1                       Abu Dhabi Airport     Abu Dhabi     Abu Dhabi
# 2    John F Kennedy International Airport  New York JFK  New York JFK
# ..                                    ...           ...           ...
# 376               Milano Malpensa Airport     Milan MXP   Mailand MXP
# 377                     Frankfurt Airport     Frankfurt     Frankfurt
# 378                        Zürich Airport        Zurich        Zürich
# 379                      Heathrow Airport    London LHR    London LHR
# 380                   Treviso Sant Angelo       Treviso       Treviso
#
#        nameEN10    nameDE10 iataCode  \
# 0        Athens       Athen      ATH
# 0        Athens       Athen      ATH
# ...

# %%
df = pd.json_normalize(
    t["monitor"]["departure"],
    sep="_",
    record_path="codeshares",
    meta=[
        "idx",
        "fn",
        "scheduledatetime",
        "schedule",
        "actualdatetime",
        "actual",
        "gate",
        "gateArea",
        ["status", "code"],
        ["status", "description"],
        ["aircraft", "type"],
        ["aircraft", "description"],
        ["airline", "name"],
        ["airline", "webSite"],
        ["airline", "iataCode"],
        ["airline", "icaoCode"],
        ["destinations", "0", "name"],
        ["destinations", "0", "iataCode"],
        ["destinations", "0", "webSite"],
        ["destinations", "0", "city", "nameEN"],
        ["destinations", "0", "city", "country", "nameEN"],
        ["checkin", "range"],
        ["checkin", "terminal"],
    ],
    errors="ignore",
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 df = pd.json_normalize(
#       2     t['monitor']['departure'],
#       3     sep='_',
#       4     record_path='codeshares',
#       5     meta=[
#       6         'idx', 'fn', 'scheduledatetime', 'schedule', 'actualdatetime', 'actual',
#       7         'gate', 'gateArea',
#       8         ['status', 'code'], ['status', 'description'],
#       9         ['aircraft', 'type'], ['aircraft', 'description'],
#      10         ['airline', 'name'], ['airline', 'webSite'], ['airline', 'iataCode'], ['airline', 'icaoCode'],
#      11         ['destinations', '0', 'name'], ['destinations', '0', 'iataCode'],
#      12         ['destinations', '0', 'webSite'], ['destinations', '0', 'city', 'nameEN'],
#      13         ['destinations', '0', 'city', 'country', 'nameEN'],
# ...

# %%
st.fromjson(
    "https://www.viennaairport.com/jart/prj3/va/data/flights/inc.json?dummy=Rbc02991Xb662233"
)
# Out:
# {'monitor': {'type': 'json',
#   'sendDate': '2024-11-19T17:19:48.272',
#   'stale': False,
#   'departure': [{'idx': 0,
#     'fn': 'FR 693',
#     'scheduledatetime': '2024-11-19T10:20:00Z',
#     'schedule': '2024-11-19T11:20:00.000',
#     'actualdatetime': '2024-11-19T10:30:00Z',
#     'actual': '2024-11-19T11:30:00.000',
#     'status': {'code': 'BLI', 'description': 'landed 11:30', 'diversion': {}},
#     'belt': {'belt': None},
#     'codeshares': [],
#     'aircraft': {'type': '320', 'description': 'Airbus 320'},
#     'airline': {'name': 'Ryanair',
#      'webSite': 'www.ryanair.com/at/de',
#      'iataCode': 'FR',
#      'icaoCode': 'RYR'},
#     'origins': [{'name': 'Manchester Airport',
#       'nameEN': 'Manchester',
#       'nameDE': 'Manchester',
#       'nameEN10': 'Manchester',
#       'nameDE10': 'Manchester',
#       'iataCode': 'MAN',
#       'webSite': 'https://www.manchesterairport.co.uk/',
#       'city': {'nameDE': 'Manchester',
# ...
